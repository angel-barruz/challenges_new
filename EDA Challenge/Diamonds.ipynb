# %%
import pandas as pd
import numpy as np
from scipy.stats import trim_mean   # conda install scipy
from statsmodels import robust     
 # conda install -c conda-forge statsmodels 
import wquantiles                   # pip install wquantiles

import seaborn as sns
import matplotlib.pylab as plt

import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import inspect

# %% [markdown]
# # DF de cada una de las tablas Diamantes

# %%
city = pd.read_csv('./data/diamonds_city_202208201411.csv')
city.head()
# Out:
#                                              city_id           city
# 0  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...      Amsterdam
# 1  1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...         Zurich
# 2  2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...      Las Vegas
# 3  5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...  New York City
# 4  5dd272b4f316b776a7b8e3d0894b37e1e42be3d5d3b204...          Paris

# %%
clarity = pd.read_csv('./data/diamonds_clarity_202208201414.csv')
clarity.head(),
#clarity.shape (8,2)
# Out:
# (                                          clarity_id clarity
#  0  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
#  1  3f9db06236e9719b61c826b612b882fa702ec81574e44c...    VVS2
#  2  66686ae1f0c9c400ba32dc600a34ff0aa173395bcbc2d8...    VVS1
#  3  7020fd7aaf1656dea5c0c0c3d4bb5a28ebf6243fba95d3...      IF
#  4  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1,)

# %%
color = pd.read_csv('./data/diamonds_color_202208201415.csv')
color.head()
# Out:
#                                             color_id color
# 0  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1  3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...     D
# 2  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 3  6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 4  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...     I

# %%
cut = pd.read_csv('./data/diamonds_cut_202208201415.csv')
cut
#cut.shape
# Out:
#                                               cut_id        cut
# 0  388655e25e91872329272fc10128ef5354b3b19a05d7e8...  Very Good
# 1  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...      Ideal
# 2  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...       Good
# 3  de88c121a82a06352bf1aaceba20578356408a334ba046...    Premium
# 4  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...       Fair

# %%
# Cargamos csv
dimensions = pd.read_csv('./data/diamonds_dimensions_202208201416.csv')
dimensions
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z
# 0      6.79  4.25
# 1      4.38  2.75
# 2      5.53  3.65
# 3      4.72  3.00
# 4      6.51  3.95
# ...     ...   ...
# 40450  7.04  4.43
# 40451  8.25  4.73
# 40452  6.42  4.01
# 40453  4.47  2.76
# 40454  6.88  4.25
#
# [40455 rows x 6 columns]

# %%
# Obtenemos df propierties
propierties = pd.read_csv('./data/diamonds_properties_202208201416.csv')
propierties
# Out:
#                                                 index_id  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...
# ...                                                  ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...
#
#                                                   cut_id  \
# 0      de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1      388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# 2      f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
# 3      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 4      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# ...                                                  ...
# 40450  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40451  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 40452  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40453  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40454  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
#
#                                                 color_id  \
# 0      6da43b944e494e885e69af021f93c6d9331c78aa228084...
# 1      44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...
# 2      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...
# 3      3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...
# ...                                                  ...
# 40450  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...
# 40452  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...
# 40453  6da43b944e494e885e69af021f93c6d9331c78aa228084...
# 40454  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...
#
#                                               clarity_id
# 0      f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...
# 1      f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...
# 2      ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...
# 3      bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...
# 4      bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...
# ...                                                  ...
# 40450  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...
# 40451  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...
# 40452  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...
# 40453  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...
# 40454  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...
#
# [40455 rows x 4 columns]

# %%
# Obtenemos df transactional
transactional = pd.read_csv('./data/diamonds_transactional_202208201417.csv')
transactional
# Out:
#                                                 index_id  price  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   4268
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...    505
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   2686
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...    738
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   4882
# ...                                                  ...    ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...  10070
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...  12615
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   5457
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...    456
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   6232
#
#                                                  city_id  carat
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...   1.21
# 1      ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...   0.32
# 2      ecc0e7dc084f141b29479058967d0bc07dee25d9690a98...   0.71
# 3      5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...   0.41
# 4      6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...   1.02
# ...                                                  ...    ...
# 40450  5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...   1.34
# 40451  1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...   2.02
# 40452  68371d5bdaab31b5cbc25fbf94b8f9c1238294fc50e715...   1.01
# 40453  5dd272b4f316b776a7b8e3d0894b37e1e42be3d5d3b204...   0.33
# 40454  ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...   1.24
#
# [40455 rows x 4 columns]

# %% [markdown]
# # Union claves con index

# %%
index_city = pd.merge(city,transactional)
index_city
# Out:
#                                                  city_id        city  \
# 0      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam
# 1      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam
# 2      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam
# 3      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam
# 4      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam
# ...                                                  ...         ...
# 40450  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...  Luxembourg
# 40451  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...  Luxembourg
# 40452  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...  Luxembourg
# 40453  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...  Luxembourg
# 40454  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...  Luxembourg
#
#                                                 index_id  price  carat
# 0      5f9c4ab08cac7457e9111a30e4664920607ea2c115a143...   6216   1.00
# 1      624b60c58c9d8bfb6ff1886c2fd605d2adeb6ea4da5760...   4969   1.16
# 2      86e50149658661312a9e0b35558d84f6c6d3da797f552a...   2422   0.70
# 3      3d914f9348c9cc0ff8a79716700b9fcd4d2f3e71160800...   3861   1.04
# 4      8722616204217eddb39e7df969e0698aed8e599ba62ed2...   2440   0.78
# ...                                                  ...    ...    ...
# 40450  6a4490713063ded3aad43f37c39037f1884a12813910ca...   7840   1.50
# 40451  eb1bc92524487e990af750137fa20dab6ae30ebb315ecf...   1058   0.39
# 40452  c6f09db9685f34691490390033c37b1bd7b13a7c6a4d48...  17392   2.02
# 40453  78b20395c3a5ff8777fb523373d519e5fede4917f1b175...   1436   0.50
# 40454  7afd6e514955f8dfb1f8540762c06dd1af7e59f7772d04...  18198   2.07
#
# [40455 rows x 5 columns]

# %%
index_clarity = pd.merge(clarity,propierties)
index_clarity
# Out:
#                                               clarity_id clarity  \
# 0      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 1      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 2      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 3      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 4      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# ...                                                  ...     ...
# 40450  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40451  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40452  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40453  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40454  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
#
#                                                 index_id  \
# 0      ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...
# 1      6b51d431df5d7f141cbececcf79edf3dd861c3b4069f0b...
# 2      8527a891e224136950ff32ca212b45bc93f69fbb801c3b...
# 3      e629fa6598d732768f7c726b4b621285f9c3b85303900a...
# 4      9400f1b21cb527d7fa3d3eabba93557a18ebe7a2ca4e47...
# ...                                                  ...
# 40450  dff43fac32be7cf4e2b5b60e653ec93e0e7b58288c2374...
# 40451  eb1d3d46da28f32f5010b2a104daf121756823531432a2...
# 40452  2a1ff30ab693f59dea389a4b12b3de2a14bcbd09aa65e3...
# 40453  26d37ebd9c73cad94e7c323e382e96cf3c3826c73d0c3c...
# 40454  5609aeee890a691e5542100acdb83a3604a4d8bd51599e...
#
#                                                   cut_id  \
# 0      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 1      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 2      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 3      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 4      de88c121a82a06352bf1aaceba20578356408a334ba046...
# ...                                                  ...
# 40450  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40451  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40452  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40453  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 40454  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
#
#                                                 color_id
# 0      f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...
# 1      a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...
# 2      44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...
# 4      3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...
# ...                                                  ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...
# 40451  a9f51566bd6705f7ea6ad54bb9deb449f795582d6529a0...
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...
# 40453  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...
# 40454  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...
#
# [40455 rows x 5 columns]

# %%
x = pd.merge(index_clarity,index_city)
x
# Out:
#                                               clarity_id clarity  \
# 0      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 1      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 2      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 3      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 4      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# ...                                                  ...     ...
# 40450  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40451  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40452  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40453  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40454  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
#
#                                                 index_id  \
# 0      ef2d127de37b942baad06145e54b0c619a1f22327b2ebb...
# 1      6b51d431df5d7f141cbececcf79edf3dd861c3b4069f0b...
# 2      8527a891e224136950ff32ca212b45bc93f69fbb801c3b...
# 3      e629fa6598d732768f7c726b4b621285f9c3b85303900a...
# 4      9400f1b21cb527d7fa3d3eabba93557a18ebe7a2ca4e47...
# ...                                                  ...
# 40450  dff43fac32be7cf4e2b5b60e653ec93e0e7b58288c2374...
# 40451  eb1d3d46da28f32f5010b2a104daf121756823531432a2...
# 40452  2a1ff30ab693f59dea389a4b12b3de2a14bcbd09aa65e3...
# 40453  26d37ebd9c73cad94e7c323e382e96cf3c3826c73d0c3c...
# 40454  5609aeee890a691e5542100acdb83a3604a4d8bd51599e...
#
#                                                   cut_id  \
# 0      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 1      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 2      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 3      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 4      de88c121a82a06352bf1aaceba20578356408a334ba046...
# ...                                                  ...
# 40450  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40451  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40452  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40453  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 40454  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
#
#                                                 color_id  \
# 0      f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...
# 1      a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...
# 2      44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...
# 4      3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...
# ...                                                  ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...
# 40451  a9f51566bd6705f7ea6ad54bb9deb449f795582d6529a0...
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...
# 40453  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...
# 40454  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...
#
#                                                  city_id       city  price  \
# 0      2bd25cd960aba8b706e2b67f2bb38b750ee5384b0e9883...  Las Vegas   9057
# 1      68371d5bdaab31b5cbc25fbf94b8f9c1238294fc50e715...   Tel Aviv   3101
# 2      ecc0e7dc084f141b29479058967d0bc07dee25d9690a98...     London  10349
# 3      89c7286890f7347ab235234e74d406596a127ae3679042...   Kimberly   6006
# 4      89c7286890f7347ab235234e74d406596a127ae3679042...   Kimberly  11078
# ...                                                  ...        ...    ...
# 40450  1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...     Zurich    863
# 40451  ba04d229e496b8383a4df91f5e77c194a95cf1a069b0b2...      Surat    702
# 40452  ecc0e7dc084f141b29479058967d0bc07dee25d9690a98...     London    490
# 40453  e9c722cbefc2f055ae60b4e2cbe73a2d99537eab0c37f3...     Madrid   9516
# 40454  ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...    Antwerp   1110
#
#        carat
# 0       1.52
# 1       0.93
# 2       1.65
# 3       1.50
# 4       1.53
# ...      ...
# 40450   0.41
# 40451   0.32
# 40452   0.28
# 40453   1.18
# 40454   0.50
#
# [40455 rows x 9 columns]

# %%
index_color = pd.merge(color,x)
index_color
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                               clarity_id clarity  \
# 0      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 1      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 2      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 3      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 4      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# ...                                                  ...     ...
# 40450  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40451  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40452  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40453  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40454  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
#
#                                                 index_id  \
# 0      e629fa6598d732768f7c726b4b621285f9c3b85303900a...
# 1      6f4b6612125fb3a0daecd2799dfd6c9c299424fd920f9b...
# 2      624b60c58c9d8bfb6ff1886c2fd605d2adeb6ea4da5760...
# 3      3d914f9348c9cc0ff8a79716700b9fcd4d2f3e71160800...
# 4      1253e9373e781b7500266caa55150e08e210bc8cd8cc70...
# ...                                                  ...
# 40450  d1672b92e93d6c436c478a6913b9134e44b0e6af419bd7...
# 40451  b68db4cf881ab5d3df809abe057021f1ca89ec3b0219c5...
# 40452  78b20395c3a5ff8777fb523373d519e5fede4917f1b175...
# 40453  dff43fac32be7cf4e2b5b60e653ec93e0e7b58288c2374...
# 40454  2a1ff30ab693f59dea389a4b12b3de2a14bcbd09aa65e3...
#
#                                                   cut_id  \
# 0      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 1      de88c121a82a06352bf1aaceba20578356408a334ba046...
# 2      de88c121a82a06352bf1aaceba20578356408a334ba046...
# 3      de88c121a82a06352bf1aaceba20578356408a334ba046...
# 4      de88c121a82a06352bf1aaceba20578356408a334ba046...
# ...                                                  ...
# 40450  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 40451  388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# 40452  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 40453  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40454  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
#
#                                                  city_id        city  price  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...    Kimberly   6006
# 1      89c7286890f7347ab235234e74d406596a127ae3679042...    Kimberly   1740
# 2      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam   4969
# 3      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam   3861
# 4      0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...   Amsterdam   9664
# ...                                                  ...         ...    ...
# 40450  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...       Dubai   1931
# 40451  89c7286890f7347ab235234e74d406596a127ae3679042...    Kimberly    905
# 40452  ed76f191621cf6ed77eab6a8013d1cb4bdfa89a75a24aa...  Luxembourg   1436
# 40453  1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...      Zurich    863
# 40454  ecc0e7dc084f141b29479058967d0bc07dee25d9690a98...      London    490
#
#        carat
# 0       1.50
# 1       0.71
# 2       1.16
# 3       1.04
# 4       1.77
# ...      ...
# 40450   0.55
# 40451   0.43
# 40452   0.50
# 40453   0.41
# 40454   0.28
#
# [40455 rows x 10 columns]

# %%
index_cut=pd.merge(index_color,cut)
index_cut
# Out:
#                                                 color_id color  \
# 0      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 1      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 2      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 3      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 4      333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...                                                  ...   ...
# 40450  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40451  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40453  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40454  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
#
#                                               clarity_id clarity  \
# 0      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 1      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 2      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 3      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 4      03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# ...                                                  ...     ...
# 40450  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40451  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40452  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40453  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 40454  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
#
#                                                 index_id  \
# 0      e629fa6598d732768f7c726b4b621285f9c3b85303900a...
# 1      27d719c754aacd492a6dc8a1b76619355abcf5ef473cbe...
# 2      4099ed5ba70aebc5a9dc26bc2093d4b45839f99b306bd1...
# 3      d74fe97872d8a425b5263add13d51a1066bf0b2cdd5e36...
# 4      92f3c34650437f1ddf6b2f2e3f4d240e6e3755bace50d4...
# ...                                                  ...
# 40450  977c3ac752ffaac24bb4c70be53ab91a064fc7f599e1f7...
# 40451  535cd5e92fb7ab31086e81c3b7bfc8dd3c8c66d3701bae...
# 40452  8cf04e6840e12f5b900bf21cda5e618b9703f8de83e546...
# 40453  ebf2ca41c95d4740c371e099474fe35a385ba21081bfe9...
# 40454  a55d1db73497a8b300470d00ca4df8833ae02a3639a159...
#
#                                                   cut_id  \
# 0      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 1      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 2      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 3      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 4      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# ...                                                  ...
# 40450  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
# 40451  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
# 40452  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
# 40453  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
# 40454  f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
#
#                                                  city_id      city  price  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...  Kimberly   6006
# 1      89c7286890f7347ab235234e74d406596a127ae3679042...  Kimberly   3246
# 2      ba04d229e496b8383a4df91f5e77c194a95cf1a069b0b2...     Surat   1009
# 3      e9c722cbefc2f055ae60b4e2cbe73a2d99537eab0c37f3...    Madrid  12929
# 4      ba04d229e496b8383a4df91f5e77c194a95cf1a069b0b2...     Surat   2363
# ...                                                  ...       ...    ...
# 40450  6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...     Dubai   2762
# 40451  ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...   Antwerp   4536
# 40452  ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...   Antwerp    982
# 40453  68371d5bdaab31b5cbc25fbf94b8f9c1238294fc50e715...  Tel Aviv    816
# 40454  89c7286890f7347ab235234e74d406596a127ae3679042...  Kimberly   3931
#
#        carat   cut
# 0       1.50  Good
# 1       0.90  Good
# 2       0.50  Good
# 3       2.02  Good
# 4       0.80  Good
# ...      ...   ...
# 40450   0.70  Fair
# 40451   0.90  Fair
# 40452   0.46  Fair
# 40453   0.34  Fair
# 40454   0.90  Fair
#
# [40455 rows x 11 columns]

# %% [markdown]
# # Unico DF

# %%
index_optimo=pd.merge(dimensions,index_cut)
index_optimo
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z                                           color_id color  \
# 0      6.79  4.25  6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 1      4.38  2.75  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 2      5.53  3.65  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 3      4.72  3.00  3f39d5c348e5b79d06e842c114e6cc571583bbf44e4b0e...     D
# 4      6.51  3.95  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# ...     ...   ...                                                ...   ...
# 40450  7.04  4.43  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G
# 40451  8.25  4.73  f67ab10ad4e4c53121b6a5fe4da9c10ddee905b978d378...     F
# 40452  6.42  4.01  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H
# 40453  4.47  2.76  6da43b944e494e885e69af021f93c6d9331c78aa228084...     J
# 40454  6.88  4.25  a83dd0ccbffe39d071cc317ddf6e97f5c6b1c87af91919...     I
#
#                                               clarity_id clarity  \
# 0      f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 1      f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 2      ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 3      bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
# 4      bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
# ...                                                  ...     ...
# 40450  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 40451  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 40452  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
# 40453  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 40454  bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
#
#                                                   cut_id  \
# 0      de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1      388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# 2      f7b19afcde965ea4942b878d266f89f8ba9a5a833e60f7...
# 3      c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 4      4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# ...                                                  ...
# 40450  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40451  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
# 40452  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40453  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# 40454  4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
#
#                                                  city_id           city  \
# 0      89c7286890f7347ab235234e74d406596a127ae3679042...       Kimberly
# 1      ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...        Antwerp
# 2      ecc0e7dc084f141b29479058967d0bc07dee25d9690a98...         London
# 3      5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...  New York City
# 4      6c425048aa7badd9d84615bd8620ca1864efd81cfdb69d...          Dubai
# ...                                                  ...            ...
# 40450  5a59ef2e40c5f89adb8c0c6ad0a8019b0e252fff530cf2...  New York City
# 40451  1e73b1647343b286269d517e6f07e6e07ccef10cd7b785...         Zurich
# 40452  68371d5bdaab31b5cbc25fbf94b8f9c1238294fc50e715...       Tel Aviv
# 40453  5dd272b4f316b776a7b8e3d0894b37e1e42be3d5d3b204...          Paris
# 40454  ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...        Antwerp
#
#        price  carat        cut
# 0       4268   1.21    Premium
# 1        505   0.32  Very Good
# 2       2686   0.71       Fair
# 3        738   0.41       Good
# 4       4882   1.02      Ideal
# ...      ...    ...        ...
# 40450  10070   1.34      Ideal
# 40451  12615   2.02       Good
# 40452   5457   1.01      Ideal
# 40453    456   0.33      Ideal
# 40454   6232   1.24      Ideal
#
# [40455 rows x 16 columns]

# %% [markdown]
# # Limpieza DataFrame

# %%
# Quitar columnas repetidas
df_optimo = index_optimo.drop(columns =['city_id','clarity_id','cut_id','color_id'] )
df_optimo
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z color clarity           city  price  carat        cut
# 0      6.79  4.25     J     VS2       Kimberly   4268   1.21    Premium
# 1      4.38  2.75     H     VS2        Antwerp    505   0.32  Very Good
# 2      5.53  3.65     G     VS1         London   2686   0.71       Fair
# 3      4.72  3.00     D     SI1  New York City    738   0.41       Good
# 4      6.51  3.95     G     SI1          Dubai   4882   1.02      Ideal
# ...     ...   ...   ...     ...            ...    ...    ...        ...
# 40450  7.04  4.43     G     VS1  New York City  10070   1.34      Ideal
# 40451  8.25  4.73     F     SI2         Zurich  12615   2.02       Good
# 40452  6.42  4.01     H     SI1       Tel Aviv   5457   1.01      Ideal
# 40453  4.47  2.76     J     VS1          Paris    456   0.33      Ideal
# 40454  6.88  4.25     I     SI1        Antwerp   6232   1.24      Ideal
#
# [40455 rows x 12 columns]

# %%
df_final=df_optimo[['index_id','depth','table','x','y','z','color','clarity','city','cut','carat','price']]
df_final
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z color clarity           city        cut  carat  price
# 0      6.79  4.25     J     VS2       Kimberly    Premium   1.21   4268
# 1      4.38  2.75     H     VS2        Antwerp  Very Good   0.32    505
# 2      5.53  3.65     G     VS1         London       Fair   0.71   2686
# 3      4.72  3.00     D     SI1  New York City       Good   0.41    738
# 4      6.51  3.95     G     SI1          Dubai      Ideal   1.02   4882
# ...     ...   ...   ...     ...            ...        ...    ...    ...
# 40450  7.04  4.43     G     VS1  New York City      Ideal   1.34  10070
# 40451  8.25  4.73     F     SI2         Zurich       Good   2.02  12615
# 40452  6.42  4.01     H     SI1       Tel Aviv      Ideal   1.01   5457
# 40453  4.47  2.76     J     VS1          Paris      Ideal   0.33    456
# 40454  6.88  4.25     I     SI1        Antwerp      Ideal   1.24   6232
#
# [40455 rows x 12 columns]

# %% [markdown]
# # CORRELACION

# %%
df_final.corr()
# Out:
#           depth     table         x         y         z     carat     price
# depth  1.000000 -0.293114 -0.026348 -0.030966  0.094655  0.026528 -0.014864
# table -0.293114  1.000000  0.196059  0.184673  0.155189  0.183392  0.130111
# x     -0.026348  0.196059  1.000000  0.973712  0.984876  0.975688  0.885848
# y     -0.030966  0.184673  0.973712  1.000000  0.964828  0.951667  0.866163
# z      0.094655  0.155189  0.984876  0.964828  1.000000  0.967570  0.874500
# carat  0.026528  0.183392  0.975688  0.951667  0.967570  1.000000  0.921935
# price -0.014864  0.130111  0.885848  0.866163  0.874500  0.921935  1.000000

# %%
df_final['cut_category'] = pd.factorize(df_final.cut)[0]
df_final['color_category'] = pd.factorize(df_final.color)[0]
df_final['clarity_category'] = pd.factorize(df_final.clarity)[0]
df_final['city_category'] = pd.factorize(df_final.city)[0]
df_final['volume']= df_final['x'] * df_final['y']*df_final['z']
# Out:
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12208\2420898419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['cut_category'] = pd.factorize(df_final.cut)[0]
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12208\2420898419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['color_category'] = pd.factorize(df_final.color)[0]
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12208\2420898419.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['clarity_category'] = pd.factorize(df_final.clarity)[0]
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12208\2420898419.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['city_category'] = pd.factorize(df_final.city)[0]
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12208\2420898419.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['volume']= df_final['x'] * df_final['y']*df_final['z']

# %%
df_final
# Out:
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z color clarity           city        cut  carat  price  \
# 0      6.79  4.25     J     VS2       Kimberly    Premium   1.21   4268
# 1      4.38  2.75     H     VS2        Antwerp  Very Good   0.32    505
# 2      5.53  3.65     G     VS1         London       Fair   0.71   2686
# 3      4.72  3.00     D     SI1  New York City       Good   0.41    738
# 4      6.51  3.95     G     SI1          Dubai      Ideal   1.02   4882
# ...     ...   ...   ...     ...            ...        ...    ...    ...
# 40450  7.04  4.43     G     VS1  New York City      Ideal   1.34  10070
# 40451  8.25  4.73     F     SI2         Zurich       Good   2.02  12615
# 40452  6.42  4.01     H     SI1       Tel Aviv      Ideal   1.01   5457
# 40453  4.47  2.76     J     VS1          Paris      Ideal   0.33    456
# 40454  6.88  4.25     I     SI1        Antwerp      Ideal   1.24   6232
#
#            volume  volume_desv  cut_category  color_category  \
# 0      197.096725   -67.294466             0               0
# 1       52.395750    77.406509             1               1
# 2      113.436890    16.365369             2               2
# 3       66.268800    63.533459             3               3
# 4      168.429975   -38.627716             4               2
# ...           ...          ...           ...             ...
# 40450  221.429120   -91.626861             4               2
# 40451  324.276975  -194.474716             3               4
# 40452  163.990554   -34.188295             4               1
# 40453   54.900540    74.901719             4               0
# 40454  199.709200   -69.906941             4               6
#
#        clarity_category  city_category
# 0                     0              0
# 1                     0              1
# 2                     1              2
# 3                     2              3
# 4                     2              4
# ...                 ...            ...
# 40450                 1              3
# 40451                 3              7
# 40452                 2              8
# 40453                 1             12
# 40454                 2              1
#
# [40455 rows x 18 columns]

# %% [markdown]
# # EDA - PRECIO

# %%
# Precio mínimo
df_final['price'].min()
# Out:
# 326

# %%
# Precio máximo
df_final['price'].max()
# Out:
# 18823

# %%
# Rango
df_final['price'].max() - df_final['price'].min()
# Out:
# 18497

# %%
# Media
df_final['price'].mean()
# Out:
# 3928.444469163268

# %%
# Mediana
mediana = df_final['price'].median()
mediana
# Como hay muchos diferencias entre precios, es más representativa la mediana respeto a la media.
# Out:
# 2397.0

# %%
# Percentiles

per_75 = df_final['price'].quantile(0.75)

per_25 = df_final['price'].quantile(0.25)

per_50 = df_final['price'].quantile(0.50) 

print('Percentile 75th:', per_75, '\nPercentile 25th:', per_25, '\nPercentile 50th:', per_50)
# Out:
# Percentile 75th: 5331.0
# Percentile 25th: 945.0
# Percentile 50th: 2397.0

# %%
df_final['price'].plot(kind='hist', bins=30, xlim=(300, 19000), figsize=(12,6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # CARAT

# %%
# Min Carat
df_final['carat'].min()
# Out:
# 0.2

# %%
# Max carat
df_final['carat'].max()
# Out:
# 4.5

# %%
# Media de Carat
df_final['carat'].mean()
# Out:
# 0.7977055988134926

# %%
# Tabla de contingencia (carat-city)

# %% [markdown]
# # Price - Carat

# %%
# Contour plot

fig, ax = plt.subplots(figsize=(10, 10))
sns.kdeplot(data=df_final.sample(10000),
            x='price',
            y='carat',
            ax=ax,
            cmap="Reds")
df_final.sample(10000).plot.scatter(x='price',
                                   y='carat',
                                   marker='$\u25EF$',
                                   alpha=1,
                                   ax=ax)
ax.set_xlabel('price')
ax.set_ylabel('carat')
plt.tight_layout()

# %%
# Relación lineal positiva. Se observa que el precio aumenta cuandi aumenta carat

# %%
# Desviación estandar para comrobar la fiabilidad de los datos
print(df_final['carat'].std())
print(df_final['price'].std())
# Out:
# 0.47554421532468527
# 3992.4161466170613

# %% [markdown]
# # VOLUME

# %%
df_final['volume'] =(df_final['x']*df_final['y']*df_final['z'])
df_final
# Out:
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12208\3378609631.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['volume'] =(df_final['x']*df_final['y']*df_final['z'])
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z color clarity           city        cut  carat  price  \
# 0      6.79  4.25     J     VS2       Kimberly    Premium   1.21   4268
# 1      4.38  2.75     H     VS2        Antwerp  Very Good   0.32    505
# 2      5.53  3.65     G     VS1         London       Fair   0.71   2686
# 3      4.72  3.00     D     SI1  New York City       Good   0.41    738
# 4      6.51  3.95     G     SI1          Dubai      Ideal   1.02   4882
# ...     ...   ...   ...     ...            ...        ...    ...    ...
# 40450  7.04  4.43     G     VS1  New York City      Ideal   1.34  10070
# 40451  8.25  4.73     F     SI2         Zurich       Good   2.02  12615
# 40452  6.42  4.01     H     SI1       Tel Aviv      Ideal   1.01   5457
# 40453  4.47  2.76     J     VS1          Paris      Ideal   0.33    456
# 40454  6.88  4.25     I     SI1        Antwerp      Ideal   1.24   6232
#
#            volume
# 0      197.096725
# 1       52.395750
# 2      113.436890
# 3       66.268800
# 4      168.429975
# ...           ...
# 40450  221.429120
# 40451  324.276975
# 40452  163.990554
# 40453   54.900540
# 40454  199.709200
#
# [40455 rows x 13 columns]

# %%
df_final.corr()
# Out:
#            depth     table         x         y         z     carat     price  \
# depth   1.000000 -0.293114 -0.026348 -0.030966  0.094655  0.026528 -0.014864
# table  -0.293114  1.000000  0.196059  0.184673  0.155189  0.183392  0.130111
# x      -0.026348  0.196059  1.000000  0.973712  0.984876  0.975688  0.885848
# y      -0.030966  0.184673  0.973712  1.000000  0.964828  0.951667  0.866163
# z       0.094655  0.155189  0.984876  0.964828  1.000000  0.967570  0.874500
# carat   0.026528  0.183392  0.975688  0.951667  0.967570  1.000000  0.921935
# price  -0.014864  0.130111  0.885848  0.866163  0.874500  0.921935  1.000000
# volume  0.006721  0.168437  0.952303  0.977860  0.953983  0.971851  0.898684
#
#           volume
# depth   0.006721
# table   0.168437
# x       0.952303
# y       0.977860
# z       0.953983
# carat   0.971851
# price   0.898684
# volume  1.000000

# %%
df_final['volume'].min()
# Out:
# 0.0

# %%
df_final['volume'].max()
# Out:
# 3840.5980600000003

# %%
df_final['volume'].std()
# Out:
# 78.90399728688193

# %%
# Media volume
df_final['volume'].mean()
# Out:
# 129.80225949284304

# %% [markdown]
# # VOLUME - PRICE

# %%
ax = df_final.plot.scatter(x='price', y='volume',
                          figsize=(10, 5),
                          marker='$\u25EF$',
                          alpha=1)
ax.set_xlabel('price')
ax.set_ylabel('volume')
ax.axhline(0, color='grey', lw=1)
ax.axvline(0, color='grey', lw=1)
plt.xlim([500, 19000])
plt.ylim([0, 4000])
plt.tight_layout()

# %%
# Desviación
df_final['volume_desv'] = df_final['volume'].mean() - df_final['volume']

print('Volume_deviation:', df_final['volume_desv'].sum())

df_final
# Out:
# Volume_deviation: -3.501736500766128e-08
# C:\Users\abarr\AppData\Local\Temp\ipykernel_12208\1812603538.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['volume_desv'] = df_final['volume'].mean() - df_final['volume']
#                                                 index_id  depth  table     x  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...   62.4   58.0  6.83
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...   63.0   57.0  4.35
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...   65.5   55.0  5.62
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...   63.8   56.0  4.68
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...   60.5   59.0  6.55
# ...                                                  ...    ...    ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...   62.7   57.0  7.10
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...   57.1   60.0  8.31
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...   62.7   56.0  6.37
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...   61.9   54.3  4.45
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...   62.0   58.0  6.83
#
#           y     z color clarity           city        cut  carat  price  \
# 0      6.79  4.25     J     VS2       Kimberly    Premium   1.21   4268
# 1      4.38  2.75     H     VS2        Antwerp  Very Good   0.32    505
# 2      5.53  3.65     G     VS1         London       Fair   0.71   2686
# 3      4.72  3.00     D     SI1  New York City       Good   0.41    738
# 4      6.51  3.95     G     SI1          Dubai      Ideal   1.02   4882
# ...     ...   ...   ...     ...            ...        ...    ...    ...
# 40450  7.04  4.43     G     VS1  New York City      Ideal   1.34  10070
# 40451  8.25  4.73     F     SI2         Zurich       Good   2.02  12615
# 40452  6.42  4.01     H     SI1       Tel Aviv      Ideal   1.01   5457
# 40453  4.47  2.76     J     VS1          Paris      Ideal   0.33    456
# 40454  6.88  4.25     I     SI1        Antwerp      Ideal   1.24   6232
#
#            volume  volume_desv
# 0      197.096725   -67.294466
# 1       52.395750    77.406509
# 2      113.436890    16.365369
# 3       66.268800    63.533459
# 4      168.429975   -38.627716
# ...           ...          ...
# 40450  221.429120   -91.626861
# 40451  324.276975  -194.474716
# 40452  163.990554   -34.188295
# 40453   54.900540    74.901719
# 40454  199.709200   -69.906941
#
# [40455 rows x 14 columns]

# %% [markdown]
# # CUT - VOLUME

# %%
# Cantidad de tipos de cut

df_final['cut'].value_counts().plot(kind='bar',title='CUT')

# Hay mas cantidad de Ideal Cut
# Out:
# <AxesSubplot:title={'center':'CUT'}>

# %%
# VOLUME - PRICE - CUT
volume_price = df_final.groupby("cut")[["volume","price"]].mean()
volume_price
# Out:
#                volume        price
# cut
# Fair       165.089080  4333.271980
# Good       135.428699  3880.611794
# Ideal      114.959765  3436.112577
# Premium    145.824334  4617.322612
# Very Good  131.210183  3994.444420

# %%
# Observamos que cut no influye sobre el precio, pero volume si

# %% [markdown]
# # Volume - Carat

# %%
df_final['volume'].mean()
# Out:
# 129.80225949284304

# %%
df_final['carat'].mean()
# Out:
# 0.7977055988134926

# %%
df_vol_carat = df_final[["volume","carat", 'price']].sort_values(by='carat').reset_index(inplace=False)
df_vol_carat
# Out:
#        index      volume  carat  price
# 0       6423   32.291558   0.20    367
# 1       1582   32.262375   0.20    345
# 2       6550   33.269760   0.20    367
# 3      16597   34.091520   0.20    367
# 4       5157   32.396364   0.20    367
# ...      ...         ...    ...    ...
# 40450   2884  627.841214   4.00  15984
# 40451   3468  631.894380   4.01  15223
# 40452  23609  621.496512   4.01  15223
# 40453  27893  633.355000   4.13  17329
# 40454  31083  698.455296   4.50  18531
#
# [40455 rows x 4 columns]

# %%
# Carat Volume - city
df_c =df_final.groupby("city")[["volume","price"]].mean()
df_c
# Out:
#                    volume        price
# city
# Amsterdam      130.815058  3965.005503
# Antwerp        129.196094  3896.202884
# Dubai          130.380668  3950.424839
# Kimberly       128.916098  3895.665675
# Las Vegas      130.427653  3988.798280
# London         130.290976  3908.619220
# Luxembourg     130.857826  3975.403328
# Madrid         129.541885  3930.299121
# New York City  130.229079  3962.377154
# Paris          130.493091  3972.697169
# Surat          130.187545  3932.422825
# Tel Aviv       128.222120  3835.473352
# Zurich         128.993837  3916.529684

# %%
ax = df_c.transpose().plot.bar(figsize=(12, 6), legend=True)
ax.set_xlabel('volume')
ax.set_ylabel('frecuency')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Color - Price

# %%
df_color = df_final[['color','price']].sort_values(by = 'color').reset_index()
df_color
# Out:
#        index color  price
# 0      38439     D   1385
# 1       5616     D   3008
# 2      21147     D    462
# 3      36113     D    663
# 4      21151     D   1130
# ...      ...   ...    ...
# 40450  25694     J   3926
# 40451  25695     J   1609
# 40452  25716     J    830
# 40453  25485     J   3326
# 40454  20227     J   3823
#
# [40455 rows x 3 columns]

# %%
# Tabla de contingencias
color = df_final.pivot_table(index=['city'],columns=['color'], aggfunc=lambda x: len(x))
color
# Out:
#               carat                                clarity            ...  \
# color             D    E    F     G    H    I    J       D    E    F  ...
# city                                                                  ...
# Amsterdam       296  482  459   516  411  256  124     296  482  459  ...
# Antwerp         624  907  928  1068  775  511  249     624  907  928  ...
# Dubai           293  430  444   550  387  234  150     293  430  444  ...
# Kimberly        624  933  925  1016  769  521  252     624  933  925  ...
# Las Vegas       324  461  431   576  368  253  145     324  461  431  ...
# London          292  459  411   550  375  261  139     292  459  411  ...
# Luxembourg      333  457  450   482  396  256  150     333  457  450  ...
# Madrid          314  448  470   526  369  227  150     314  448  470  ...
# New York City   341  469  431   480  434  223  117     341  469  431  ...
# Paris           334  451  449   516  419  267  143     334  451  449  ...
# Surat           611  902  852  1105  817  510  250     611  902  852  ...
# Tel Aviv        328  468  430   512  413  259  123     328  468  430  ...
# Zurich          335  458  497   558  344  254  148     335  458  497  ...
#
#                  y              z
# color            H    I    J    D    E    F     G    H    I    J
# city
# Amsterdam      411  256  124  296  482  459   516  411  256  124
# Antwerp        775  511  249  624  907  928  1068  775  511  249
# Dubai          387  234  150  293  430  444   550  387  234  150
# Kimberly       769  521  252  624  933  925  1016  769  521  252
# Las Vegas      368  253  145  324  461  431   576  368  253  145
# London         375  261  139  292  459  411   550  375  261  139
# Luxembourg     396  256  150  333  457  450   482  396  256  150
# Madrid         369  227  150  314  448  470   526  369  227  150
# New York City  434  223  117  341  469  431   480  434  223  117
# Paris          419  267  143  334  451  449   516  419  267  143
# Surat          817  510  250  611  902  852  1105  817  510  250
# Tel Aviv       413  259  123  328  468  430   512  413  259  123
# Zurich         344  254  148  335  458  497   558  344  254  148
#
# [13 rows x 84 columns]
